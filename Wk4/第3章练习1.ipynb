# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
data=pd.read_csv('data\students.csv')
data
# Out:
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 0     1    male   20     170      70      LiaoNing  100.0       800        5
# 1     2    male   22     180      71       GuangXi   77.0      1300        3
# 2     3    male   21     180      62        FuJian   57.0      1000        2
# 3     4    male   20     177      72      LiaoNing   79.0       900        4
# 4     5    male   20     172      64      ShanDong   91.0      1200        5
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 6     7  female   21     166      53      LiaoNing   80.0      1200        4
# 7     8  female   20     162      47         AnHui   78.0      1000        4
# 8     9  female   20     162      47         AnHui   78.0      1000        4
# 9    10    male   19     169      76  HeiLongJiang   88.0      1100        5
# 10   11  female   21     162      49        YunNan   89.0       800        5
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
data.columns
# Out:
# Index(['No.', 'Gender', 'Age', 'Height', 'Weight', 'Province', 'Score',
#        'MonthFee', 'Courses', 'CaseTeaching'],
#       dtype='object')

# %%
data.values
# Out:
# array([[1, 'male', 20, 170, 70, 'LiaoNing', 100.0, 800, 5, 4],
#        [2, 'male', 22, 180, 71, 'GuangXi', 77.0, 1300, 3, 4],
#        [3, 'male', 21, 180, 62, 'FuJian', 57.0, 1000, 2, 4],
#        [4, 'male', 20, 177, 72, 'LiaoNing', 79.0, 900, 4, 4],
#        [5, 'male', 20, 172, 64, 'ShanDong', 91.0, 1200, 5, 5],
#        [6, 'male', 20, 179, 75, 'YunNan', 92.0, 950, 5, 5],
#        [7, 'female', 21, 166, 53, 'LiaoNing', 80.0, 1200, 4, 5],
#        [8, 'female', 20, 162, 47, 'AnHui', 78.0, 1000, 4, 4],
#        [9, 'female', 20, 162, 47, 'AnHui', 78.0, 1000, 4, 4],
#        [10, 'male', 19, 169, 76, 'HeiLongJiang', 88.0, 1100, 5, 5],
#        [11, 'female', 21, 162, 49, 'YunNan', 89.0, 800, 5, 5],
#        [12, 'female', 20, 164, 53, 'GuiZhou', 79.0, 1000, 4, 5],
#        [13, 'female', 20, 166, 43, 'HaiNan', 12.0, 1000, 5, 5],
#        [14, 'female', 21, 162, 52, 'TianJin', 86.0, 500, 5, 5],
#        [15, 'male', 20, 175, 73, 'AnHui', nan, 700, 4, 4],
# ...

# %%
data.shape
# Out:
# (50, 10)

# %%
data.loc[:,['Age','Score']]
# Out:
#     Age  Score
# 0    20  100.0
# 1    22   77.0
# 2    21   57.0
# 3    20   79.0
# 4    20   91.0
# 5    20   92.0
# 6    21   80.0
# 7    20   78.0
# 8    20   78.0
# 9    19   88.0
# 10   21   89.0
# 11   20   79.0
# 12   20   12.0
# 13   21   86.0
# 14   20    NaN
# 15   19   75.0
# 16   21   74.0
# 17   20   79.0
# 18   21   61.0
# 19   19   56.0
# 20   21   93.0
# 21   19   89.0
# 22   21   93.0
# 23   21   59.0
# 24   21   68.0
# 25   21   62.0
# 26   21   65.0
# 27   22   73.0
# 28   20   80.0
# 29   20   98.0
# 30   21   92.0
# 31   20   63.0
# 32   20   77.0
# 33   21   62.0
# 34   20   97.0
# 35   21   87.0
# 36   21   95.0
# 37   19   63.0
# 38   19   64.0
# 39   21   62.0
# 40   19   91.0
# 41   21   89.0
# 42   21   93.0
# 43   20   82.0
# 44   20   87.0
# 45   21   71.0
# 46   21   73.0
# 47   21   64.0
# 48   21   81.0
# 49   20   76.0

# %%
data.iloc[[1,5,10]]
# Out:
#     No.  Gender  Age  Height  Weight Province  Score  MonthFee  Courses  \
# 1     2    male   22     180      71  GuangXi   77.0      1300        3
# 5     6    male   20     179      75   YunNan   92.0       950        5
# 10   11  female   21     162      49   YunNan   89.0       800        5
#
#     CaseTeaching
# 1              4
# 5              5
# 10             5

# %%
data.head(5)
# Out:
#    No. Gender  Age  Height  Weight  Province  Score  MonthFee  Courses  \
# 0    1   male   20     170      70  LiaoNing  100.0       800        5
# 1    2   male   22     180      71   GuangXi   77.0      1300        3
# 2    3   male   21     180      62    FuJian   57.0      1000        2
# 3    4   male   20     177      72  LiaoNing   79.0       900        4
# 4    5   male   20     172      64  ShanDong   91.0      1200        5
#
#    CaseTeaching
# 0             4
# 1             4
# 2             4
# 3             4
# 4             5

# %%
data.loc[10,'Score']=100
data
# Out:
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 0     1    male   20     170      70      LiaoNing  100.0       800        5
# 1     2    male   22     180      71       GuangXi   77.0      1300        3
# 2     3    male   21     180      62        FuJian   57.0      1000        2
# 3     4    male   20     177      72      LiaoNing   79.0       900        4
# 4     5    male   20     172      64      ShanDong   91.0      1200        5
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 6     7  female   21     166      53      LiaoNing   80.0      1200        4
# 7     8  female   20     162      47         AnHui   78.0      1000        4
# 8     9  female   20     162      47         AnHui   78.0      1000        4
# 9    10    male   19     169      76  HeiLongJiang   88.0      1100        5
# 10   11  female   21     162      49        YunNan  100.0       800        5
# ...

# %%
data1=data[data.loc[:,"Score"]>90]
data1
# Out:
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 0     1    male   20     170      70      LiaoNing  100.0       800        5
# 4     5    male   20     172      64      ShanDong   91.0      1200        5
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 10   11  female   21     162      49        YunNan  100.0       800        5
# 20   21  female   21     165      45      ShangHai   93.0      1200        5
# 22   23    male   21     169      80         GanSu   93.0       900        5
# 29   30  female   20     168      52       JiangSu   98.0       700        5
# 30   31  female   21     162      45         JiLin   92.0      1400        5
# 34   35    male   20     171      66      ShangHai   97.0       650        5
# 36   37    male   21     177      68      XinJiang   95.0       500        5
# 40   41    male   19     174      63  HeiLongJiang   91.0       600        5
# ...

# %%
data1.to_csv('d:\\a.csv',mode='w')

# %%
data.insert(0,'city','shanghai')
data
# Out:
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 0     1    male   20     170      70      LiaoNing  100.0       800        5
# 1     2    male   22     180      71       GuangXi   77.0      1300        3
# 2     3    male   21     180      62        FuJian   57.0      1000        2
# 3     4    male   20     177      72      LiaoNing   79.0       900        4
# 4     5    male   20     172      64      ShanDong   91.0      1200        5
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 6     7  female   21     166      53      LiaoNing   80.0      1200        4
# 7     8  female   20     162      47         AnHui   78.0      1000        4
# 8     9  female   20     162      47         AnHui   78.0      1000        4
# 9    10    male   19     169      76  HeiLongJiang   88.0      1100        5
# 10   11  female   21     162      49        YunNan  100.0       800        5
# ...

# %%
print(data.drop(np.arange(10,16),inplace=False))
data
# Out:
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 0     1    male   20     170      70      LiaoNing  100.0       800        5
# 1     2    male   22     180      71       GuangXi   77.0      1300        3
# 2     3    male   21     180      62        FuJian   57.0      1000        2
# 3     4    male   20     177      72      LiaoNing   79.0       900        4
# 4     5    male   20     172      64      ShanDong   91.0      1200        5
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 6     7  female   21     166      53      LiaoNing   80.0      1200        4
# 7     8  female   20     162      47         AnHui   78.0      1000        4
# 8     9  female   20     162      47         AnHui   78.0      1000        4
# 9    10    male   19     169      76  HeiLongJiang   88.0      1100        5
# 16   17    male   21     178      79       GuiZhou   74.0       650        4
# ...

# %%
print(data.drop(np.arange(5),inplace=False))
data
# Out:
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 6     7  female   21     166      53      LiaoNing   80.0      1200        4
# 7     8  female   20     162      47         AnHui   78.0      1000        4
# 8     9  female   20     162      47         AnHui   78.0      1000        4
# 9    10    male   19     169      76  HeiLongJiang   88.0      1100        5
# 10   11  female   21     162      49        YunNan  100.0       800        5
# 11   12  female   20     164      53       GuiZhou   79.0      1000        4
# 12   13  female   20     166      43        HaiNan   12.0      1000        5
# 13   14  female   21     162      52       TianJin   86.0       500        5
# 14   15    male   20     175      73         AnHui    NaN       700        4
# 15   16    male   19     172      20      ShanDong   75.0       900        5
# ...

# %%
data=data.drop(data[data.loc[:,"Courses"]==3].index)
data
# Out:
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 0     1    male   20     170      70      LiaoNing  100.0       800        5
# 2     3    male   21     180      62        FuJian   57.0      1000        2
# 3     4    male   20     177      72      LiaoNing   79.0       900        4
# 4     5    male   20     172      64      ShanDong   91.0      1200        5
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 6     7  female   21     166      53      LiaoNing   80.0      1200        4
# 7     8  female   20     162      47         AnHui   78.0      1000        4
# 8     9  female   20     162      47         AnHui   78.0      1000        4
# 9    10    male   19     169      76  HeiLongJiang   88.0      1100        5
# 10   11  female   21     162      49        YunNan  100.0       800        5
# 11   12  female   20     164      53       GuiZhou   79.0      1000        4
# ...

# %%
#data[data.loc[:,"CaseTeaching"]==5][data.loc[:,"Courses"]==4].loc[:,"CaseTeaching"]=8
label1=data[data.loc[:,"CaseTeaching"]==5].index
label2=data[data.loc[:,"Courses"]==4].index
label=np.intersect1d(label1, label2)
print(label)
data.loc[label,"CaseTeaching"]=8
data
# Out:
# [ 6 11 16 17 24 32 41 43 46]
#     No.  Gender  Age  Height  Weight      Province  Score  MonthFee  Courses  \
# 0     1    male   20     170      70      LiaoNing  100.0       800        5
# 2     3    male   21     180      62        FuJian   57.0      1000        2
# 3     4    male   20     177      72      LiaoNing   79.0       900        4
# 4     5    male   20     172      64      ShanDong   91.0      1200        5
# 5     6    male   20     179      75        YunNan   92.0       950        5
# 6     7  female   21     166      53      LiaoNing   80.0      1200        4
# 7     8  female   20     162      47         AnHui   78.0      1000        4
# 8     9  female   20     162      47         AnHui   78.0      1000        4
# 9    10    male   19     169      76  HeiLongJiang   88.0      1100        5
# 10   11  female   21     162      49        YunNan  100.0       800        5
# 11   12  female   20     164      53       GuiZhou   79.0      1000        4
# ...

# %%
grouped = data.groupby("Gender")
grouped.aggregate({"Score":np.mean, "MonthFee":np.mean})
# Out:
#             Score    MonthFee
# Gender
# female  75.590909  977.272727
# male    82.380952  890.909091

# %%
grouped.aggregate({"Height":np.max, "Weight":np.min, "Score":np.max, "Score":np.min, "Score":[np.max, np.min, np.mean]})
# Out:
#        Height Weight  Score
#          amax   amin   amax  amin       mean
# Gender
# female    168     42  100.0  12.0  75.590909
# male      181     20  100.0  57.0  82.380952
