# %%
import pandas as pd

# %%
# 'advertising.csv' instead of 'Advertising.csv'
data = pd.read_csv(r'data/advertising.csv')
advdata = data[['TV','Weibo','WeChat']]
# 绘制各类经费收入的箱形图
advdata.plot(kind='box', figsize=(6,6),
            title='Advertising Expenditure')
# Out:
# <AxesSubplot:title={'center':'Advertising Expenditure'}>
